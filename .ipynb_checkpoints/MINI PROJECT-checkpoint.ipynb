# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
import pickle
with open(r"C:\Users\tejes\Desktop\MINI PROJECT\dev_letter_D.p","rb") as f:
    db=pickle.load(f,encoding='bytes')
print("number of letter images in the dataset are:",str(len(db)))
# Out:
# number of letter images in the dataset are: 7702

# %% [markdown]
# This dataset has been created for the research and development of a Sanskrit OCR.
# The dataset contains 7702 images of sanskrit(Devanagari) letters belonging to 602 classes.

# %% [markdown]
# The dataset is structured in the following manner:
# 	The data is in the form of a 2D array.
# 	The first dimension indicates the indexed letter in the dataset.
# 	The second dimension is again a 1D dimensional array containing three elements-
# 		 The first element is the image in array form.
# 		 The second element is the corresponding class index number.
# 		 The third element is the corresponding English class Annotation.

# %%
i=59
try:
    img=db[i][0]
    class_index=db[i][1]
    class_annoation=db[i][2]
    resized_img=cv2.resize(img,(200,200))
    cv2.imshow("Sanskrit image",resized_img)
    cv2.waitKey(1000)
    cv2.destroyAllWindows()
    print("the class index number of the sanskrit letter image is:"+str(class_index))
    print("the class annotation of the sanskrit letter image is:"+str(class_annoation))
except:
    print("index out of range")
# Out:
# the class index number of the sanskrit letter image is:41
# the class annotation of the sanskrit letter image is:cha

# %% [markdown]
# ## Info of Dataset

# %%
print("dataset length:",len(db))
print("the dataset type is:",type(db))
print("first entry:",[db[0]])
# Out:
# dataset length: 7702
# the dataset type is: <class 'list'>
# first entry: [[array([[[211, 243, 254],
#         [211, 243, 254],
#         [210, 242, 253],
#         ...,
#         [199, 227, 234],
#         [197, 225, 232],
#         [198, 226, 233]],
#
#        [[210, 242, 253],
#         [210, 242, 253],
#         [208, 240, 251],
#         ...,
#         [205, 233, 240],
#         [197, 225, 232],
#         [188, 216, 223]],
#
#        [[208, 240, 251],
#         [208, 240, 251],
#         [206, 238, 249],
#         ...,
#         [210, 237, 244],
#         [199, 226, 233],
#         [179, 206, 212]],
#
#        ...,
#
#        [[210, 240, 251],
#         [211, 241, 251],
#         [212, 242, 252],
#         ...,
#         [217, 246, 250],
#         [216, 246, 250],
#         [216, 245, 250]],
#
#        [[210, 240, 251],
#         [211, 241, 251],
#         [213, 242, 251],
#         ...,
#         [216, 245, 249],
#         [216, 246, 250],
#         [215, 245, 249]],
#
#        [[211, 241, 252],
#         [211, 240, 251],
#         [210, 239, 249],
#         ...,
#         [211, 240, 245],
#         [213, 242, 247],
#         [213, 242, 247]]], dtype=uint8), 0, 'i']]

# %% [markdown]
# ## Checking any Malformed Entries

# %%
for i,entry in enumerate(db):
    if isinstance(entry,list) and len(entry)==3:
        if not isinstance(entry[0],np.ndarray):
            print(f"entry {i} is not a numpy array")
    else:
        print(f"malformed entry at index {i}:{entry}")
    if i>=15:
        break

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
try:
    images=np.array([np.array(entry[0]) for entry in db])
    lables=np.array([entry[1] for entry in db])

    images=images.astype('float32')/255.0

    num_classes=len(set(lables))
    lables=to_categorical(lables,num_classes)

    if len(images.shape)==3:
        images=images[...,np.newaxis]

    x_train,x_temp,y_train,y_temp=train_test_split(images,lables,test_size=0.3,random_state=42)
    x_val,x_test,y_val,y_test=train_test_split(x_temp,y_temp,test_size=0.5,random_state=42)

    print("Preprocessing completed successfully")
    print("x_train shape:",x_train.shape)
    print("y_train shape:",y_train.shape)
    print("x_val shape:",x_val.shape)
    print("y_val shape:",y_val.shape)
    print("x_test shape:",x_test.shape)
    print("y_test shape:",y_test.shape)

except Exception as e:
    print(f"Error in preprocessing:{e}")
# Out:
# Preprocessing completed successfully
# x_train shape: (5391, 32, 32, 3)
# y_train shape: (5391, 600)
# x_val shape: (1155, 32, 32, 3)
# y_val shape: (1155, 600)
# x_test shape: (1156, 32, 32, 3)
# y_test shape: (1156, 600)

# %% [markdown]
# ## Creation of Models

# %%
from tensorflow.keras import models,layers

model=models.Sequential()


model.add (layers.Conv2D(32,(3,3),activation='relu',input_shape=x_train.shape[1:]))
model.add(layers.MaxPooling2D((2,2)))


model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(128,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())

model.add(layers.Dense(128,activation='relu'))

model.add(layers.Dense(num_classes,activation='softmax'))

model.summary()
# Out:
# c:\Users\tejes\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 600)            │        77,400 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 236,312 (923.09 KB)
#  Trainable params: 236,312 (923.09 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compile The Model

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## Train The Model

# %%
history=model.fit(x_train,y_train,epochs=40,validation_data=(x_val,y_val))
# Out:
# Epoch 1/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9817 - loss: 0.0623 - val_accuracy: 0.7671 - val_loss: 3.8920
# Epoch 2/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9748 - loss: 0.0833 - val_accuracy: 0.7576 - val_loss: 3.5900
# Epoch 3/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9851 - loss: 0.0506 - val_accuracy: 0.7489 - val_loss: 3.8091
# Epoch 4/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9764 - loss: 0.0757 - val_accuracy: 0.7342 - val_loss: 3.9182
# Epoch 5/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9814 - loss: 0.0565 - val_accuracy: 0.7472 - val_loss: 3.5755
# Epoch 6/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9786 - loss: 0.0689 - val_accuracy: 0.7429 - val_loss: 3.8574
# Epoch 7/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9799 - loss: 0.0776 - val_accuracy: 0.7455 - val_loss: 3.9461
# Epoch 8/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9808 - loss: 0.0693 - val_accuracy: 0.7377 - val_loss: 3.6675
# Epoch 9/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9855 - loss: 0.0473 - val_accuracy: 0.7610 - val_loss: 3.7570
# Epoch 10/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9808 - loss: 0.0671 - val_accuracy: 0.7610 - val_loss: 3.8284
# Epoch 11/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9775 - loss: 0.0727 - val_accuracy: 0.7489 - val_loss: 4.0930
# Epoch 12/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9778 - loss: 0.0732 - val_accuracy: 0.7636 - val_loss: 3.8168
# Epoch 13/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9833 - loss: 0.0543 - val_accuracy: 0.7524 - val_loss: 4.0281
# Epoch 14/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9861 - loss: 0.0473 - val_accuracy: 0.7628 - val_loss: 4.0710
# Epoch 15/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9879 - loss: 0.0423 - val_accuracy: 0.7506 - val_loss: 4.1820
# Epoch 16/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9766 - loss: 0.0708 - val_accuracy: 0.7359 - val_loss: 3.6581
# Epoch 17/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9859 - loss: 0.0422 - val_accuracy: 0.7532 - val_loss: 3.9629
# Epoch 18/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9845 - loss: 0.0458 - val_accuracy: 0.7680 - val_loss: 3.8509
# Epoch 19/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9867 - loss: 0.0451 - val_accuracy: 0.7437 - val_loss: 3.5903
# Epoch 20/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9860 - loss: 0.0481 - val_accuracy: 0.7515 - val_loss: 3.7175
# Epoch 21/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9784 - loss: 0.0772 - val_accuracy: 0.7307 - val_loss: 4.0818
# Epoch 22/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9720 - loss: 0.0886 - val_accuracy: 0.7420 - val_loss: 4.0850
# Epoch 23/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9841 - loss: 0.0645 - val_accuracy: 0.7411 - val_loss: 3.9040
# Epoch 24/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9870 - loss: 0.0436 - val_accuracy: 0.7567 - val_loss: 3.9438
# Epoch 25/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9889 - loss: 0.0343 - val_accuracy: 0.7654 - val_loss: 3.5813
# Epoch 26/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9943 - loss: 0.0263 - val_accuracy: 0.7654 - val_loss: 3.8367
# Epoch 27/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9928 - loss: 0.0236 - val_accuracy: 0.7619 - val_loss: 4.2882
# Epoch 28/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9886 - loss: 0.0363 - val_accuracy: 0.7680 - val_loss: 3.7295
# Epoch 29/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9944 - loss: 0.0216 - val_accuracy: 0.7515 - val_loss: 3.5619
# Epoch 30/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9865 - loss: 0.0403 - val_accuracy: 0.7411 - val_loss: 4.1309
# Epoch 31/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9812 - loss: 0.0543 - val_accuracy: 0.7281 - val_loss: 3.9264
# Epoch 32/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9723 - loss: 0.0802 - val_accuracy: 0.7351 - val_loss: 3.9053
# Epoch 33/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9730 - loss: 0.0817 - val_accuracy: 0.7584 - val_loss: 4.0239
# Epoch 34/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9895 - loss: 0.0417 - val_accuracy: 0.7610 - val_loss: 4.1204
# Epoch 35/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9908 - loss: 0.0307 - val_accuracy: 0.7576 - val_loss: 3.8181
# Epoch 36/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9875 - loss: 0.0383 - val_accuracy: 0.7550 - val_loss: 3.8539
# Epoch 37/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9914 - loss: 0.0277 - val_accuracy: 0.7714 - val_loss: 3.7416
# Epoch 38/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9871 - loss: 0.0396 - val_accuracy: 0.7550 - val_loss: 4.1659
# Epoch 39/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9933 - loss: 0.0272 - val_accuracy: 0.7567 - val_loss: 3.8128
# Epoch 40/40
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9890 - loss: 0.0288 - val_accuracy: 0.7593 - val_loss: 3.8617

# %% [markdown]
# ## Evaluate The Model

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print(f"Test accuracy:{test_acc*100:.2f}%")
print(f"Test loss:{test_loss:.4f}")
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7535 - loss: 4.7348
# Test accuracy:76.04%
# Test loss:4.5234

# %% [markdown]
# ## Plotting Model Performance

# %%
import matplotlib.pyplot as plt

#plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

#plot training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Defining The Hyperparameter Search Space

# %%
from kerastuner import Hyperband

def build_model(hp):
    model=models.Sequential()

    model.add(layers.Conv2D(filters=hp.Choice('conv_1_filter',values=[32,64,128]),kernel_size=hp.Choice('conv_1_kernel',values=[3,5]),activation='relu',input_shape=x_train.shape[1:]))
    model.add(layers.MaxPooling2D((2,2)))

    model.add(layers.Conv2D(filters=hp.Choice('conv_2_filter',values=[32,64,128]),kernel_size=hp.Choice('conv_2_kernel',values=[3,5]),activation='relu'))
    model.add(layers.MaxPooling2D((2,2)))

    model.add(layers.Dropout(hp.Choice('dropout_rate',values=[0.2,0.3,0.5])))
    

    model.add(layers.Flatten())

    model.add(layers.Dense(units=hp.Choice('dense_units',values=[128,256,512]),activation='relu'))

    model.add(layers.Dense(num_classes,activation='softmax'))

    model.compile(optimizer=hp.Choice('optimizer',values=['adam','sgd']),loss='categorical_crossentropy',metrics=['accuracy'])

    return model
# Out:
# C:\Users\tejes\AppData\Local\Temp\ipykernel_31084\3728495379.py:1: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner import Hyperband

# %% [markdown]
# ## Hyperband Search

# %%
from kerastuner.tuners import Hyperband

tuner=Hyperband(build_model,
                objective='val_accuracy',
                max_epochs=40,
                factor=3,
                directory='tuner_dir',
                project_name='Sanskrit_OCR')
# Out:
# Reloading Tuner from tuner_dir\Sanskrit_OCR\tuner0.json

# %%
tuner.search(x_train,y_train,epochs=10,validation_data=(x_val,y_val))

# %%
# Evaluate the best-tuned model on the test set
test_loss, test_acc = build_model.evaluate(x_test, y_test)

# Print the test accuracy and loss
print(f"Hypertuned model test accuracy: {test_acc * 100:.2f}%")
print(f"Hypertuned model test loss: {test_loss:.4f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Evaluate the best-tuned model on the test set
# ----> 2 test_loss, test_acc = build_model.evaluate(x_test, y_test)
#       4 # Print the test accuracy and loss
#       5 print(f"Hypertuned model test accuracy: {test_acc * 100:.2f}%")
#
# AttributeError: 'function' object has no attribute 'evaluate'

# %%
import matplotlib.pyplot as plt

# Assuming `history` is the training history of the original model
# Retrieve the best model and its training history
best_model = tuner.get_best_models(num_models=1)[0]
best_history = best_model.fit(x_train, y_train, epochs=10, validation_data=(x_val, y_val))
# Out:
# WARNING:tensorflow:From c:\Users\tejes\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/10
# c:\Users\tejes\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9437 - loss: 0.2086 - val_accuracy: 0.7697 - val_loss: 2.4093
# Epoch 2/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9479 - loss: 0.1722 - val_accuracy: 0.7714 - val_loss: 2.5176
# Epoch 3/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9446 - loss: 0.1854 - val_accuracy: 0.7645 - val_loss: 2.4521
# Epoch 4/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9510 - loss: 0.1646 - val_accuracy: 0.7628 - val_loss: 2.5446
# Epoch 5/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9499 - loss: 0.1694 - val_accuracy: 0.7541 - val_loss: 2.6673
# Epoch 6/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9543 - loss: 0.1566 - val_accuracy: 0.7636 - val_loss: 2.6732
# Epoch 7/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9668 - loss: 0.1334 - val_accuracy: 0.7654 - val_loss: 2.7785
# Epoch 8/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9571 - loss: 0.1541 - val_accuracy: 0.7610 - val_loss: 3.0570
# Epoch 9/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9613 - loss: 0.1314 - val_accuracy: 0.7567 - val_loss: 2.7459
# Epoch 10/10
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9597 - loss: 0.1317 - val_accuracy: 0.7662 - val_loss: 2.7234

# %%
# Plot training accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Original Train Accuracy')
plt.plot(best_history.history['accuracy'], label='Tuned Train Accuracy')
plt.title('Training Accuracy Before and After Hyperparameter Tuning')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# %%
# Plot validation accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['val_accuracy'], label='Original Validation Accuracy')
plt.plot(best_history.history['val_accuracy'], label='Tuned Validation Accuracy')
plt.title('Validation Accuracy Before and After Hyperparameter Tuning')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# %%
# Save the original model
model.save('original_model.h5')
print("Original model saved as 'original_model.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Original model saved as 'original_model.h5'

# %%
# Retrieve the best model from the tuner
best_model = tuner.get_best_models(num_models=1)[0]

# Save the best tuned model
best_model.save('best_tuned_model.h5')
print("Best tuned model saved as 'best_tuned_model.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Best tuned model saved as 'best_tuned_model.h5'

# %%
class_map = {
    0: "अ", 1: "आ", 2: "इ", 3: "ई", 4: "उ", 5: "ऊ", 6: "ऋ", 7: "ॠ", 8: "ऌ", 9: "ॡ",
    10: "ऍ", 11: "ऎ", 12: "ए", 13: "ऐ", 14: "ऑ", 15: "ऒ", 16: "ओ", 17: "औ",
    18: "क", 19: "ख", 20: "ग", 21: "घ", 22: "ङ",
    23: "च", 24: "छ", 25: "ज", 26: "झ", 27: "ञ",
    28: "ट", 29: "ठ", 30: "ड", 31: "ढ", 32: "ण",
    33: "त", 34: "थ", 35: "द", 36: "ध", 37: "न",
    38: "प", 39: "फ", 40: "ब", 41: "भ", 42: "म",
    43: "य", 44: "र", 45: "ल", 46: "व",
    47: "श", 48: "ष", 49: "स", 50: "ह",
    51: "ळ", 52: "क्ष", 53: "ज्ञ", 54: "त्र",
    55: "श्र", 56: "ज्ञ", 57: "क्ष", 58: "श्र", 59: "ज्ञ", 60: "क्ष",
    61: "त्र", 62: "ज्ञ", 63: "श्र", 64: "ट्र", 65: "ड्र",
    66: "तृ", 67: "थृ", 68: "दृ", 69: "धृ", 70: "नृ",
    71: "पृ", 72: "फृ", 73: "बृ", 74: "भृ", 75: "मृ",
    76: "यर", 77: "रर", 78: "लर", 79: "वर",
    80: "सर", 81: "शर", 82: "षर", 83: "हर",
    84: "ळर", 85: "क्ष", 86: "ज्ञ", 87: "त्र",
    88: "श्र", 89: "ज्ञ", 90: "क्ष", 91: "त्र",
    92: "ज्ञ", 93: "श्र", 94: "ट्र", 95: "ड्र",
    96: "तृ", 97: "थृ", 98: "दृ", 99: "धृ",
    100: "नृ", 101: "पृ", 102: "फृ", 103: "बृ",
    104: "भृ", 105: "मृ", 106: "यर", 107: "रर",
    108: "लर", 109: "वर", 110: "सर", 111: "शर",
    112: "षर", 113: "हर", 114: "ळर", 115: "क्ष",
    116: "ज्ञ", 117: "त्र", 118: "श्र", 119: "ज्ञ",
    120: "क्ष", 121: "त्र", 122: "ज्ञ", 123: "श्र",
    124: "ट्र", 125: "ड्र", 126: "तृ", 127: "थृ",
    128: "दृ", 129: "धृ", 130: "नृ", 131: "पृ",
    132: "फृ", 133: "बृ", 134: "भृ", 135: "मृ",
    136: "यर", 137: "रर", 138: "लर", 139: "वर",
    140: "सर", 141: "शर", 142: "षर", 143: "हर",
    144: "ळर", 145: "क्ष", 146: "ज्ञ", 147: "त्र",
    148: "श्र", 149: "ज्ञ", 150: "क्ष", 151: "त्र",
    152: "ज्ञ", 153: "श्र", 154: "ट्र", 155: "ड्र",
    156: "तृ", 157: "थृ", 158: "दृ", 159: "धृ",
    160: "नृ", 161: "पृ", 162: "फृ", 163: "बृ",
    164: "भृ", 165: "मृ", 166: "यर", 167: "रर",
    168: "लर", 169: "वर", 170: "सर", 171: "शर",
    172: "षर", 173: "हर"
}

# Predict the class for multiple test images
num_predictions = 50  # Set the number of images you want to predict
for i in range(num_predictions):
    test_image = x_test[i:i+1]  # Select one image from the test set
    prediction = model.predict(test_image)  # Get the prediction for that image
    decoded_letter = class_map[np.argmax(prediction)]  # Decode the prediction
    predicted_class_index = np.argmax(prediction)  # Get the predicted class index
    
    # Print the predicted class index and decoded letter
    print(f"Prediction for image {i + 1}:")
    print(f"Predicted class index: {predicted_class_index}")
    print(f"Decoded Sanskrit letter: {decoded_letter}")
    print("-" * 30)  # Separator for readability
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Prediction for image 1:
# Predicted class index: 173
# Decoded Sanskrit letter: हर
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Prediction for image 2:
# Predicted class index: 40
# Decoded Sanskrit letter: ब
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Prediction for image 3:
# Predicted class index: 26
# Decoded Sanskrit letter: झ
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Prediction for image 4:
# Predicted class index: 62
# Decoded Sanskrit letter: ज्ञ
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Prediction for image 5:
# Predicted class index: 50
# Decoded Sanskrit letter: ह
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Prediction for image 6:
# Predicted class index: 41
# Decoded Sanskrit letter: भ
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Prediction for image 7:
# Predicted class index: 40
# Decoded Sanskrit letter: ब
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 48
#      46 test_image = x_test[i:i+1]  # Select one image from the test set
#      47 prediction = model.predict(test_image)  # Get the prediction for that image
# ---> 48 decoded_letter = class_map[np.argmax(prediction)]  # Decode the prediction
#      49 predicted_class_index = np.argmax(prediction)  # Get the predicted class index
#      51 # Print the predicted class index and decoded letter
#
# KeyError: 267
